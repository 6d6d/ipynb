# %% [markdown]
# <a href="https://colab.research.google.com/github/6d6d/ipynb/blob/main/GPT2_Chinese.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <module>
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms)
#     103       force_remount=force_remount,
#     104       timeout_ms=timeout_ms,
# --> 105       ephemeral=True)
#     106
#     107
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral)
#     118   if ephemeral:
#     119     _message.blocking_request(
# --> 120         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     121
#     122   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
# !cp -r /content/drive/MyDrive/Save/GPT2-Chinese/ /content/

# %%
# !cp -r /content/drive/Shareddrives/"fake news"/Python/GPT2-Chinese /content/

# %%
# %cd GPT2-Chinese
# !pip install -r requirements.txt
# Out:
# /content/GPT2-Chinese
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 311 kB 28.3 MB/s
# ...
#      |████████████████████████████████| 880 kB 54.2 MB/s
# ...
#      |████████████████████████████████| 132 kB 68.5 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 63.0 MB/s
# ...
#      |████████████████████████████████| 79 kB 9.2 MB/s
# ...
#      |████████████████████████████████| 9.1 MB 69.0 MB/s
# ...
#      |████████████████████████████████| 140 kB 73.8 MB/s
# ...
#      |████████████████████████████████| 127 kB 69.3 MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=0966b7853bd55ac8fd1c05766071f6ca956f2fa3fefa340c0ec8f9f51b674328
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built sacremoses
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
# ...

# %%
# !python train_single.py --raw
# !python train_single.py
# Out:
# 2022-08-29 17:03:15.945710: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=4, device='0,1,2,3', epochs=15, fp16=False, fp16_opt_level='O1', gradient_accumulation=1, log_step=10, lr=0.00015, max_grad_norm=1.0, model_config='model/model_epoch5/config.json', num_pieces=100, output_dir='model/', pretrained_model='model/model_epoch5', raw=False, raw_data_path='data/train.json', segment=False, stride=768, tokenized_data_path='data/tokenized/', tokenizer_path='model/model_epoch5/vocab.txt', warmup_steps=2000)
# config:
# {
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 10,
#   "n_positions": 1024,
#   "num_labels": 1,
#   "output_attentions": false,
# ...

# %%
# !cp -r /content/GPT2-Chinese/ /content/drive/Shareddrives/"fake news"/Save/"8.30"
# !cp -r /content/GPT2-Chinese/ /content/drive/MyDrive/Save/"8.30"
