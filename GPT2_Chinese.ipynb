# %% [markdown]
# <a href="https://colab.research.google.com/github/6d6d/ipynb/blob/main/GPT2_Chinese.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/Save/GPT2-Chinese/ /content/

# %%
# %cd /content/
# !rm -rf GPT2-Chinese
# %cd /content/GPT2-Chinese/model/
# !rm -rf 0928
# !rm -rf 092801
# !rm -rf final_model-092802

# %%
# !cp -r /content/drive/Shareddrives/DAY/Save/GPT/GPT2-Chinese-Upload/ /content/GPT2-Chinese

# %%
# %cd GPT2-Chinese
# !pip install -r requirements.txt

# %%
# !rm -rf /content/GPT2-Chinese/data/tokenized

# %%
# !rm -rf /content/GPT2-Chinese/tensorboard_summary

# %%
# !python train.py --raw
# !python train_single.py --raw
# !python train_single.py
# Out:
# 2022-10-16 05:54:16.043391: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=5, bpe_token=False, device='0,1,2,3', encoder_json='tokenizations/encoder.json', epochs=36, fp16=False, fp16_opt_level='O1', gradient_accumulation=1, log_step=5, lr=0.00015, max_grad_norm=1.0, min_length=250, model_config='config/model_config_jiaoan.json', num_pieces=10, output_dir='model/', pretrained_model='', raw=True, raw_data_path='data/1015.json', segment=False, stride=750, tokenized_data_path='data/tokenized/', tokenizer_path='cache/vocab_1015.txt', vocab_bpe='tokenizations/vocab.bpe', warmup_steps=2000, writer_dir='tensorboard_summary/')
# config:
# {
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 768,
# ...

# %%
# !cp -r /content/GPT2-Chinese/ /content/drive/Shareddrives/DAY/Save/GPT/1016e40
# !cp -r /content/GPT2-Chinese/ /content/drive/Shareddrives/DAY2DAY/Save/GPT/1016e40
# !cp -r /content/GPT2-Chinese/ /content/drive/MyDrive/Save/"8.30"

# %%
# !cp -r /content/GPT2-Chinese/model/final_model /content/drive/Shareddrives/DAY/Save/GPT/Model/1016e40
# !cp -r /content/GPT2-Chinese/model/final_model /content/drive/Shareddrives/DAY2DAY/Save/GPT/Model/1016e40

# %%
# !cp -r /content/GPT2-Chinese/tensorboard_summary /content/drive/Shareddrives/DAY/Save/GPT/Tensorboard/1016e40
# !cp -r /content/GPT2-Chinese/tensorboard_summary /content/drive/Shareddrives/DAY2DAY/Save/GPT/Tensorboard/1016e40

# %%
# !cp -r /content/drive/Shareddrives/DAY/Save/GPT/GPT2-Chinese-Upload /content/drive/Shareddrives/DAY2DAY/Save/GPT/GPT2-Chinese-Upload

# %%
# !python generate.py
# Out:
# 2022-10-16 07:23:39.549318: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# args:
# Namespace(batch_size=1, device='0,1,2,3', fast_pattern=False, length=-1, model_config='model/final_model/config.json', model_path='model/final_model', no_wordpiece=False, nsamples=5, prefix='课文标题', repetition_penalty=1.0, save_samples=False, save_samples_path='.', segment=False, temperature=1, tokenizer_path='cache/vocab_1015.txt', topk=8, topp=0)
# model.config=
#  {
#   "attn_pdrop": 0.1,
#   "embd_pdrop": 0.1,
#   "finetuning_task": null,
#   "initializer_range": 0.02,
#   "layer_norm_epsilon": 1e-05,
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_layer": 10,
#   "n_positions": 1024,
#   "num_labels": 1,
#   "output_attentions": false,
#   "output_hidden_states": false,
#   "output_past": true,
#   "pruned_heads": {},
#   "resid_pdrop": 0.1,
# ...

# %%
# !python eval.py
