# %% [markdown]
# <a href="https://colab.research.google.com/github/6d6d/ipynb/blob/main/Cogview_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 一些注意事项

# %% [markdown]
# 登陆我在群里发的帐号，在代码执行程序——更改运行选择时类型选择GPU、高ARM后一段代码一段代码点击运行，因为其中过程中要修改文件。

# %%
#这段代码是远程连接至本地的，不需要理会
# !pip install colab_ssh --upgrade

# from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
# launch_ssh_cloudflared(password="11111111")

# %%
# !git clone https://github.com/THUDM/CogView.git
#把代码文件克隆过来，注意！这里要进入Cogview的代码的文件夹（没出现的话邮件文件栏点击刷新（但是不是刷新整个网页）），然后要在CogView目录下创建input.txt文件，在里面每一行写一个想生成的句子。
#然后再进入scripts/text2image.sh文件把里面max-inference-batch-size后面的数字从4改成1（因为内存不够，不改的话会内存溢出）
# Out:
# Cloning into 'CogView'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 200 (delta 20), reused 11 (delta 11), pack-reused 169
# Receiving objects: 100% (200/200), 12.67 MiB | 34.96 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#卸载torch
# !pip uninstall torch torchvision torchaudi torchtext -y
#安装旧版torch
# !pip install torch==1.10.0+cu111 torchvision==0.11.0+cu111 torchaudio==0.10.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Found existing installation: torch 1.12.0+cu113
# Uninstalling torch-1.12.0+cu113:
#   Successfully uninstalled torch-1.12.0+cu113
# Found existing installation: torchvision 0.13.0+cu113
# Uninstalling torchvision-0.13.0+cu113:
#   Successfully uninstalled torchvision-0.13.0+cu113
# WARNING: Skipping torchaudi as it is not installed.
# Found existing installation: torchtext 0.13.0
# Uninstalling torchtext-0.13.0:
#   Successfully uninstalled torchtext-0.13.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %%
# !pip install deep_translator lmdb
#安装一些包
# !pip install -r CogView/requirements.txt
# !git clone https://github.com/NVIDIA/apex
# %cd /content/apex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 128 kB 45.5 MB/s
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 578 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 58.0 MB/s
# ...
#      |████████████████████████████████| 2.5 MB 58.7 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 216 kB 54.9 MB/s
# ...
#      |████████████████████████████████| 54 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 108 kB 67.9 MB/s
# ...
#      |████████████████████████████████| 99 kB 11.0 MB/s
# ...

# %% [markdown]
# #在运行下面那一栏之前：修改该apex文件夹中的setup.py文件
#
# #将setup.py文件中的这一段代码
#
# if (bare_metal_major != torch_binary_major) or (bare_metal_minor != torch_binary_minor):
# raise RuntimeError("Cuda extensions are being compiled with a version of Cuda that does " +
# "not match the version used to compile Pytorch binaries. " +
# "Pytorch binaries were compiled with Cuda {}.\n".format(torch.version.cuda) +
# "In some cases, a minor-version mismatch will not cause later errors: " +
# "https://github.com/NVIDIA/apex/pull/323#discussion_r287021798. "
# "You can try commenting out this check (at your own risk).")
#
# 全部注释掉或者删除掉
#
# # if (bare_metal_major != torch_binary_major) or (bare_metal_minor != torch_binary_minor):
# # raise RuntimeError("Cuda extensions are being compiled with a version of Cuda that does " +
# # "not match the version used to compile Pytorch binaries. " +
# # "Pytorch binaries were compiled with Cuda {}.\n".format(torch.version.cuda) +
# # "In some cases, a minor-version mismatch will not cause later errors: " +
# # "https://github.com/NVIDIA/apex/pull/323#discussion_r287021798. "
# # "You can try commenting out this check (at your own risk).")
# 注释掉之后继续运行下面的代码

# %%
#要运行一段时间，出现报错但没有停止运行的话就不要紧，如果停止运行说明上一步没做～（或者其他原因）
# !pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext"  --global-option="--cuda_ext"  ./
# Out:
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:232: UserWarning: Disabling all use of wheels due to the use of --build-option / --global-option / --install-option.
#   cmdoptions.check_install_build_global(options)
# Using pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# ...

# %%
#下载model，此处要等待许久
# %cd /content/

model_link = "https://the-eye.eu/public/AI/CogView/cogview-base.tar" #@param {type: "string"}


using_google_drive_id = False #@param {type: "boolean"}

if using_google_drive_id:
  # !gdown "$model_link" -O /content/cogview-base.tar --id
else:
  # !wget "$model_link" -O /content/cogview-base.tar



# !tar -xvf /content/cogview-base.tar -C /content/CogView/pretrained/cogview/



print("Finished")
# Out:
# cogview-base/
# cogview-base/142000/
# cogview-base/142000/mp_rank_00_model_states.pt
# cogview-base/latest_checkpointed_iteration.txt
# cogview-base/latest
# Finished

# %%
#下载vqvae
# !wget "https://www.dropbox.com/s/lk78djywfdw9na1/vqvae_hard_biggerset_011.pt?dl=1" -O /content/CogView/pretrained/vqvae/vqvae_hard_biggerset_011.pt

# %%
# !cp /content/vqvae_hard_biggerset_011.pt?dl=1 /content/drive/MyDrive

# %%
# !nvidia-smi
#这个代码可以看看咱们的显卡是啥

# %%
DS_BUILD_SPARSE_ATTN=1#这里好像可有可无，我没试过删掉会不会成功运行

# %%
#先在cogview目录创建一个input.txt文件，里面每行放一个要生成的照片的文字～
# %cd /content/CogView
# !scripts/text2image.sh --debug
#要等待一段时间运行，如果出现show raw text:你输入中文，然后再等一下就应该可以在 samples_text2image里看到生成的照片了，这里运行比较慢
#有可能会运行一下就断了，看一看报错，如果跟内存有关就说明可能没有进入scripts/text2image.sh文件把里面max-inference-batch-size后面的数字从4改成1
#再去改一下，再直接运行这一栏的代码就行了。然后如果还不行可以尝试把.sh文件中的batch-size后面的数字改成1（这个是决定每个文本生成多少张图片的）
#如果是其他bug可以截图来让我康康
#每次运行完这段代码可以改input.txt文件里的字后重新运行这段代码的（不需要从头）
